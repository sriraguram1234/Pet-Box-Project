# %% [markdown]
# # Data Analyst Associate Case Study Submission
# # Case Study Project - Pet Box Subscription

# %% [markdown]
# ## Data Validation
# There were total of 89 Rows and 9 columns in the original Dataset .First, I analysed the dataset and used conditional formatting to check the blank cells, Hopefully there were no blank cells.After that , I checked the data types of each column. I changed product_id from integer to string and re_buy from integer to binary. I realized that the data in the sales column was separated by commas, So that I validated and changed the data type from string to integer.Column pet_type has 6 types , Based on the requirement , I removed to type named hamster and rabbit.

# %% [markdown]
#  Finally the Dataset was ready for Analysis.
# - There were no blank cells.
# - Pet type only has 4 variables,they were dog,cat,fish,bird.
# - Data types of product_id,Vendor_id were changed to string.
# - Sales column was validated and converted to integer.
# - re_buy column changed from integer to Binary.

# %% [markdown]
# ## Data Discovery and Visualization
# Lets see about the insights from data visuaization.
#
# ### **1. How many products are being purchased more than once?**
#
# There were total of 879 products, Out of this 390 products were purchased more than once and 443 products were purchased once in the year.46.81% of total products are purchased more than once and 53.19% of total products were purchased once in the year.

# %% [markdown]
# ![Breakdown by category](./qw1.jpg)

# %% [markdown]
# Based on the requirement That has to create two different visualization for one variable. So that I add Bar chart for same question.

# %% [markdown]
# ![Breakdown by category](qw2.jpg)

# %% [markdown]
# ### **2. Do the products being purchased again have better sales than others?**
#
# There are total 11 category of products were present. By comparing the sales for all category on the basis of the product whether they were purchased again or not. By seeing the result,The sales of the category such as toys, Supplements, Snacks,Medicine,Grooming, Clothes has better sales for products which were not purchased again. The sales of category such as Accesories,Bedding,
# Food, Equipment and Housing has better sales for the products which were purchased again.Conclude with average sales for products in different category which were purchased again has less compared with product which were purchased once.

# %% [markdown]
# ![Breakdown by category](q5.png)

# %% [markdown]
# ### **3. What products are more likely to be purchased again for different types of pets?**
#
# There are total 11 categories of products were presented in the dataset. Based on the insights from the probability distribution graph for different pet types.

# %% [markdown]
# First, We are going to see the probability distribution graph for **dogs**. Based on the visualization. Equipments,Supplements and Toys are the categories most likely to buy.
# The probability of buying Equipment,Supplements and Toys are 14.697% each.

# %% [markdown]
# ![Breakdown by category](dog.png)

# %% [markdown]
# Its time for **cat**. Based on the visualization.Equipments and Toys are the categories most likely to buy. Snacks comes next.
# The probability of buying Equipment and Toys are 14.697% each And the probability of buying snacks is 14.409%.

# %% [markdown]
# ![Breakdown by category](cat.png)

# %% [markdown]
# We are going to see the probability distribution graph for **birds**. Based on the visualization. Equipments is the categories most likely to buy. The probability of buying Equipment is 26.09% each. And the probability of buying snacks and toys are 24.64% each.

# %% [markdown]
# ![Breakdown by category](bird.png)

# %% [markdown]
# Now, Its time for **fish**. Based on the visualization.Snacks and Toys are the categories most likely to buy. Equipments comes next. The probability of buying Snacks and Toys are 25.71% each And the probability of buying snacks is 24.29%.

# %% [markdown]
# ![Breakdown by category](fish.png)

# %% [markdown]
# ### Tools Used
# - SQL
# - TABLEAU
